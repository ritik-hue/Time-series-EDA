# %% [markdown]
# <a href="https://colab.research.google.com/github/ritik-hue/Time-series-EDA/blob/main/timeseries_projection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas_datareader import data as pdr
import pandas as pd
from datetime import datetime
import yfinance as yf

# %%
yf.pdr_override()
df1=pdr.get_data_yahoo('TSLA')
df1
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
# 2023-07-12  276.329987  276.519989  271.459991  271.989990  271.989990
# 2023-07-13  274.589996  279.450012  270.600006  277.899994  277.899994
# 2023-07-14  277.010010  285.299988  276.309998  281.380005  281.380005
#
#                Volume
# Date
# ...

# %%
df1.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df1['High'].plot(xlim=['2020-01-01','2020-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df1['High'].plot(xlim=['2020-01-01','2020-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df1['High'].plot(xlim=['2020-01-01','2020-09-01'],ylim=[0,900],figsize=(12,4),ls='--',c='blue')
# Out:
# <Axes: xlabel='Date'>

# %%
df1.loc['2020-09-01':'2021-01-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-01  167.380005  167.496674  156.836670  158.350006  158.350006
# 2020-09-02  159.663330  159.679993  135.039993  149.123337  149.123337
# 2020-09-03  135.743332  143.933334  134.000000  135.666672  135.666672
# 2020-09-04  134.270004  142.666672  124.006668  139.440002  139.440002
# 2020-09-08  118.666664  122.913330  109.959999  110.070000  110.070000
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume
# Date
# 2020-09-01  269523300
# 2020-09-02  288528300
# 2020-09-03  262788300
# ...

# %%
share_open=df1.loc['2020-09-01':'2021-01-01']['Open']
index=df1.loc['2020-09-01':'2021-01-01'].index
share_open
# Out:
# Date
# 2020-09-01    167.380005
# 2020-09-02    159.663330
# 2020-09-03    135.743332
# 2020-09-04    134.270004
# 2020-09-08    118.666664
#                  ...
# 2020-12-24    214.330002
# 2020-12-28    224.836670
# 2020-12-29    220.333328
# 2020-12-30    224.000000
# 2020-12-31    233.330002
# Name: Open, Length: 85, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
df1.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-10  276.470001  277.519989  265.100006  269.609985  269.609985
# 2023-07-11  268.649994  270.899994  266.369995  269.790009  269.790009
# 2023-07-12  276.329987  276.519989  271.459991  271.989990  271.989990
# 2023-07-13  274.589996  279.450012  270.600006  277.899994  277.899994
# 2023-07-14  277.010010  285.299988  276.309998  281.380005  281.380005
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# ...

# %%
df1=df1.reset_index()

# %%
df1=df1.set_index('Date',drop=True)

# %%
date=datetime(2023,7,16)

# %%
date.weekday()
# Out:
# 6

# %%
##year end frequency=rule a
df1.resample(rule="A").max()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#search resample function of pandas
df1.resample(rule="QS").max()["High"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1["High"].resample(rule="BQS").max().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
